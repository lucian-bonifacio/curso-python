# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Comando utilizado para manter a reprodutibilidade do codigo quando trabalhamos com funçoes aleatorias

import random
random.seed(1)

# %%
# Importando a biblioteca numpy

import numpy as np

# %%
# Cria as matrizes de entrada e saida. Neste caso, é a tabela verdade da funçao logica AND (E)
#Cada lista é uma linha e cada item de lista é uma coluna.

entradas = np.array([ [0,0],[0,1],[1,0],[1,1] ])
saidas = np.array([[0,0,0,1]]).T

# %%
entradas
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
saidas
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])

# %%
# Cria as matrizes de pesos da rede neural - w

w1 = 2*np.random.random((2,4)) - 1
w2 = 2*np.random.random((4,1)) - 1

# %%
w1
# Out:
# array([[-0.67286564,  0.83109846, -0.21329211,  0.57041567],
#        [-0.42210242, -0.60571424,  0.44282306,  0.00259504]])

# %%
w2
# Out:
# array([[-0.49533722],
#        [-0.25050546],
#        [ 0.54668738],
#        [-0.65227584]])

# %%
# Treinamento da rede neural

for interacao in range(1000000):
    camada1 = 1 / (1 + np.exp(-(np.dot(entradas,w1))))
    camada2 = 1 / (1 + np.exp(-(np.dot(camada1,w2))))
    camada2_delta = (saidas - camada2)*(camada2*(1-camada2))
    camada1_delta = camada2_delta.dot(w2.T) * (camada1 * (1-camada1))
    w2 += camada1.T.dot(camada2_delta)
    w1 += entradas.T.dot(camada1_delta)

# %%
camada2
# Out:
# array([[4.55541175e-05],
#        [1.01355651e-03],
#        [5.51923954e-04],
#        [9.98726222e-01]])

# %%
# Verificando a saida da rede

camada2.round()
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [1.]])
